# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns
from termcolor import colored

df = pd.read_json("scout_car.json", lines=True)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# ...

# %%
df.head().T
# Out:
#                                                                                0  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# ...

# %%
df.describe(include=object).T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   15919     48
# prev_owner                      9091      4
# hp                             15919     81
# Type                           15917    169
# Previous Owners                 9279    102
# Next Inspection                 3535   1399
# Inspection new                  3932    202
# Warranty                       10499    515
# Full Service                    8215    122
# Non-smoking Vehicle             7177     94
# null                           15919      1
# Make                           15919      3
# Model                          15919      9
# Offer Number                   12744  11440
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
# ...

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# ...

# %%
df.rename(columns = {'\nComfort & Convenience\n':'Comfort & Convenience', 
                     '\nEntertainment & Media\n':'Entertainment & Media',
                     '\nExtras\n':'Extras',
                     '\nSafety & Security\n':'Safety & Security'}, inplace = True)

# %%
df.T
# Out:
#                                                                            0      \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')
df.T
# Out:
#                                                                            0      \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# ...

# %%
df['weight_kg'] = df.Weight.str[0].str.replace(',', '').str.strip('\n').str.strip('kg')
df['weight_kg'].T
# Out:
# 0        1220
# 1        1255
# 2          NaN
# 3        1195
# 4          NaN
#          ...
# 15914    1758
# 15915    1708
# 15916      NaN
# 15917    1758
# 15918    1685
# Name: weight_kg, Length: 15919, dtype: object

# %%
df.drop(["url"], axis=1, inplace=True)

# %%
df.Make
# Out:
# 0           \nAudi\n
# 1           \nAudi\n
# 2           \nAudi\n
# 3           \nAudi\n
# 4           \nAudi\n
#             ...
# 15914    \nRenault\n
# 15915    \nRenault\n
# 15916    \nRenault\n
# 15917    \nRenault\n
# 15918    \nRenault\n
# Name: Make, Length: 15919, dtype: object

# %%
df['Make'] = df['Make'].map(lambda x : x.strip('\n'), na_action = 'ignore')

# %%
df['Make'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object>

# %%
df[['make_model', 'Make', 'Model']].sample(20)
# Out:
#           make_model     Make               Model
# 13153   Renault Clio  Renault      [\n, Clio, \n]
# 5188         Audi A3     Audi        [\n, A3, \n]
# 2814         Audi A3     Audi        [\n, A3, \n]
# 8395      Opel Corsa     Opel     [\n, Corsa, \n]
# 2738         Audi A3     Audi        [\n, A3, \n]
# 6682      Opel Astra     Opel     [\n, Astra, \n]
# 9152      Opel Corsa     Opel     [\n, Corsa, \n]
# 7264      Opel Astra     Opel     [\n, Astra, \n]
# 3915         Audi A3     Audi        [\n, A3, \n]
# 12546  Opel Insignia     Opel  [\n, Insignia, \n]
# 11436  Opel Insignia     Opel  [\n, Insignia, \n]
# 4261         Audi A3     Audi        [\n, A3, \n]
# 12579  Opel Insignia     Opel  [\n, Insignia, \n]
# 5761      Opel Astra     Opel     [\n, Astra, \n]
# 2078         Audi A1     Audi        [\n, A1, \n]
# 14692   Renault Clio  Renault      [\n, Clio, \n]
# 1146         Audi A1     Audi        [\n, A1, \n]
# 14008   Renault Clio  Renault      [\n, Clio, \n]
# ...

# %%
df.make_model.unique()
# Out:
# array(['Audi A1', 'Audi A2', 'Audi A3', 'Opel Astra', 'Opel Corsa',
#        'Opel Insignia', 'Renault Clio', 'Renault Duster',
#        'Renault Espace'], dtype=object)

# %%
df.make_model.value_counts()
# Out:
# Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64

# %%
df.make_model.isnull().sum()
# Out:
# 0

# %%
df.drop(["Make", "Model"], axis=1, inplace=True)
df.T
# Out:
#                                                                            0      \
# make_model                                                               Audi A1
# short_description                    Sportback 1.4 TDI S-tronic Xenon Navi Klima
# body_type                                                                 Sedans
# price                                                                      15770
# vat                                                               VAT deductible
# km                                                                     56,013 km
# registration                                                             01/2016
# prev_owner                                                     2 previous owners
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# ...

# %%
df[['body_type', 'Body']].sample(20)
# Out:
#       body_type                Body
# 7523     Sedans    [\n, Sedans, \n]
# 15751       Van       [\n, Van, \n]
# 7990     Sedans    [\n, Sedans, \n]
# 243      Sedans    [\n, Sedans, \n]
# 443      Sedans    [\n, Sedans, \n]
# 8498     Sedans    [\n, Sedans, \n]
# 14905  Off-Road  [\n, Off-Road, \n]
# 5170     Sedans    [\n, Sedans, \n]
# 10009    Sedans    [\n, Sedans, \n]
# 6825     Sedans    [\n, Sedans, \n]
# 7538     Sedans    [\n, Sedans, \n]
# 15816       Van       [\n, Van, \n]
# 2084     Sedans    [\n, Sedans, \n]
# 795      Sedans    [\n, Sedans, \n]
# 5379     Sedans    [\n, Sedans, \n]
# 11285     Other     [\n, Other, \n]
# 9083     Sedans    [\n, Sedans, \n]
# 2520     Sedans    [\n, Sedans, \n]
# 12060    Sedans    [\n, Sedans, \n]
# 948      Sedans    [\n, Sedans, \n]

# %%
df.price.isnull().sum()
# Out:
# 0

# %%
df[df.price == 'nan'].value_counts().sum()
# Out:
# 0

# %%
df[['registration', 'First_Registration']].isnull().sum()
# Out:
# registration             0
# First_Registration    1597
# dtype: int64

# %%
df[['registration', 'First_Registration']].sample(5)
# Out:
#       registration First_Registration
# 9575       03/2018     [\n, 2018, \n]
# 13662      05/2017     [\n, 2017, \n]
# 14469      02/2018     [\n, 2018, \n]
# 1456       07/2018     [\n, 2018, \n]
# 15797      06/2019     [\n, 2019, \n]

# %%
df['registration'].head()
# Out:
# 0    01/2016
# 1    03/2017
# 2    02/2016
# 3    08/2016
# 4    05/2016
# Name: registration, dtype: object

# %%
df['registration'].value_counts()
# Out:
# -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64

# %%
df['registration'].map(lambda x : x[3:], na_action= 'ignore')
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: registration, Length: 15919, dtype: object

# %%
df['registration'] = df['registration'].map(lambda x : x[3:], na_action= 'ignore')

# %%
df['registration'] = pd.to_numeric(df['registration'], errors='coerce')

# %%
df['age']= 2019 - df['registration']
df['age']
# Out:
# 0        3.0
# 1        2.0
# 2        3.0
# 3        3.0
# 4        3.0
#         ...
# 15914    NaN
# 15915    0.0
# 15916    0.0
# 15917    0.0
# 15918    0.0
# Name: age, Length: 15919, dtype: float64

# %%
df['age'].value_counts()
# Out:
# 1.0    4522
# 3.0    3674
# 2.0    3273
# 0.0    2853
# Name: age, dtype: int64

# %%
df[['prev_owner', 'Previous_Owners']].isnull().sum()
# Out:
# prev_owner         6828
# Previous_Owners    6640
# dtype: int64

# %%
df[['prev_owner', 'Previous_Owners']].sample(10)
# Out:
#              prev_owner Previous_Owners
# 3398               None             NaN
# 6207               None             NaN
# 9788   1 previous owner           \n1\n
# 12312  1 previous owner           \n1\n
# 5654   1 previous owner           \n1\n
# 6110   1 previous owner           \n1\n
# 11353  1 previous owner           \n1\n
# 706                None             NaN
# 6631   1 previous owner           \n1\n
# 7831               None             NaN

# %%
df['kW'].isnull().sum()
# Out:
# 15919

# %%
df['hp'].value_counts()
# Out:
# 85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
#           ...
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 9 kW         1
# Name: hp, Length: 81, dtype: int64

# %%
df['hp_kw'] = df['hp'].str.strip(' kW').replace('-', np.nan).astype(float)
df['hp_kw']
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: hp_kw, Length: 15919, dtype: float64

# %%
df['hp_kw'].value_counts()
# Out:
# 85.0     2542
# 66.0     2122
# 81.0     1402
# 100.0    1308
# 110.0    1112
#          ...
# 137.0       1
# 9.0         1
# 44.0        1
# 133.0       1
# 239.0       1
# Name: hp_kw, Length: 80, dtype: int64

# %%
df['Type'].head(3)
# Out:
# 0    [, Used, , Diesel (Particulate Filter)]
# 1                       [, Used, , Gasoline]
# 2    [, Used, , Diesel (Particulate Filter)]
# Name: Type, dtype: object

# %%
df['Type'].map(lambda x : x[1], na_action='ignore')
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %%
df['Type'] = df['Type'].map(lambda x : x[1], na_action='ignore')

# %%
df['Type'].value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df['Fuel'].astype('str').value_counts()
# Out:
# ['\n', 'Diesel (Particulate Filter)', '\n']                                                                                  4315
# ['\n', 'Super 95', '\n']                                                                                                     3338
# ['\n', 'Gasoline', '\n']                                                                                                     3175
# ['\n', 'Diesel', '\n']                                                                                                       2984
# ['\n', 'Super 95 / Regular/Benzine 91', '\n']                                                                                 424
#                                                                                                                              ...
# ['\n', 'Regular/Benzine 91 / Super 95 / Regular/Benzine E10 91', '\n']                                                          1
# ...

# %%
df.drop(["null", "short_description", 'Body', 'First_Registration', 'prev_owner', 'kW', 'hp'], axis=1, inplace=True)
