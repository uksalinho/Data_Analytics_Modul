# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/6gCsHd6/1200px-Pandas-logo-svg.png width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Session - 07</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Handling with Missing Values</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Content</p>
#
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#0)
# * [TYPE OF NAN VALUES](#1)
# * [DETECTING MISSING VALUES](#2)
# * [CONVERTING INAPPROPRIATE VALUES TO NAN VALUES](#3)
# * [MISSING VALUE HANDLING METHODS](#4)
# * [THE END OF THE SESSION - 07](#5)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Importing Libraries Needed in This Notebook</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy & Pandas you can import them as a library:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
id_no = ["P001", "P002", "P003", "P004", "P005", "P006", "P007", "P008", "P009", "P010", "P011"]
gender = ["M", "F", "M", "F", "M", "F", "M", "F", "M", "F", "M"]
status = ["FT", "PT", "-", "FT", "PT", "PT", "FT", "-", "PT", "FT", np.nan]  # listelere her tipte veri koyulabilir
dept = ["DS", "FS", "AWS", "AWS", "DS", None, "FS", "FS", np.nan, "DS", "AWS"]
V1 = np.array([2, 3, 5, np.nan, 7, 1, np.nan, 10, 14, "-", 6])  # array'de tüm datalari ayni tipte üretiyordi. "-" string ifadesi hepsinden üstün oldugundan hepsini string olarak üretti
V2 = np.array([8, np.nan, 5, 8, 11, np.nan, np.nan, 2, 3, 7, 9])  # array, the same data type
salary = np.array([np.nan, 54, 59, 120, 58, 75, None, 136, 60, 125, np.nan])

df = pd.DataFrame({
                   "id" : id_no,
                   "gender": gender,
                   "status": status,
                   "dept": dept,
                   "var1" : V1,
                   "var2" : V2,
                   "salary" : salary
                  })
df
 # listelere her tipte veri koyulabilir.
 # array, the same data type.
 # array'de tüm datalari ayni tipte üretiyordi, bu yüzden 
 # "-" string ifadesi hepsinden üstün oldugundan hepsini string olarak üretti
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Type of NaN Values</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     object
#  1   gender  11 non-null     object
#  2   status  10 non-null     object
#  3   dept    9 non-null      object
#  4   var1    11 non-null     object
#  5   var2    8 non-null      float64
#  6   salary  8 non-null      object
# dtypes: float64(1), object(6)
# memory usage: 744.0+ bytes

# %%
type(np.nan)
# Out:
# float

# %%
type(np.NaN)
# Out:
# float

# %%
type(None)
# Out:
# NoneType

# %%
df.salary  # array, the same data type.
           # None daha üstün old. column'un genel dtype: object
           # ama asagida özelde 1'e-1 bakildiginda kendi dtyp'lerini veriyor
# Out:
# 0      NaN
# 1       54
# 2       59
# 3      120
# 4       58
# 5       75
# 6     None
# 7      136
# 8       60
# 9      125
# 10     NaN
# Name: salary, dtype: object

# %%
type(df.salary[0])
# Out:
# float

# %%
type(df.salary[6])
# Out:
# NoneType

# %%
type(df.salary[1])
# Out:
# int

# %%
df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
type(df.status[2])
# Out:
# str

# %%
type(df.status[10])
# Out:
# float

# %%
df.var1  # hepsi string
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
type(df.var1[3])
# Out:
# str

# %%
type(df.var1[1])
# Out:
# str

# %%
type(df.var1[9])
# Out:
# str

# %%
print(1, 0 * np.nan)
print(2, np.nan == np.nan)
print(3, np.inf > np.nan)
print(4, np.nan - np.nan)
print(5, np.nan + np.nan)
print(6, np.nan - 10)
print(7, np.nan + 10)
print(8, np.nan in set([np.nan]))
print(9, 0.3 == 3 * 0.1)
# Out:
# 1 nan
# 2 False
# 3 False
# 4 nan
# 5 nan
# 6 nan
# 7 nan
# 8 True
# 9 False

# %%
a = np.nan

# %%
b = np.nan

# %%
id(a)
# Out:
# 1985063642992

# %%
id(b)
# Out:
# 1985063642992

# %% [markdown]
# **What is the None keyword in Python? [ANSWER01](https://www.educative.io/edpresso/what-is-the-none-keyword-in-python), [ANSWER02](https://stackoverflow.com/questions/21095654/what-is-a-nonetype-object)**
#
# **Difference between None and NaN in Pandas [ANSWER01](https://www.skytowner.com/explore/difference_between_none_and_nan_in_pandas), [ANSWER02](https://kegui.medium.com/what-is-the-difference-between-nan-none-pd-nan-and-np-nan-a8ee0532e2eb)**
#
# **Difference between np.nan and np.NaN [ANSWER](https://stackoverflow.com/questions/53436339/difference-between-np-nan-and-np-nan)**
#
# **Difference between nan and 'nan' in Python [ANSWER01](https://stackoverflow.com/questions/40309789/difference-between-nan-and-nan-in-python), [ANSWER02](https://towardsdatascience.com/navigating-the-hell-of-nans-in-python-71b12558895b)**

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Detecting Missing Values</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **``NaN``**, standing for "Not A Number", is a numeric data type used to represent any value that is undefined or unpresentable.
#
# For example, 0/0 is undefined as a real number and is, therefore, represented by NaN. The square root of a negative number is an imaginary number that cannot be represented as a real number, so, it is represented by NaN.
#
# **``NaN``** is also assigned to variables, in a computation, that do not have values and have yet to be computed.

# %%
df
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 2   P003      M      -   AWS    5   5.0     59
# 3   P004      F     FT   AWS  nan   8.0    120
# 4   P005      M     PT    DS    7  11.0     58
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 7   P008      F      -    FS   10   2.0    136
# 8   P009      M     PT   NaN   14   3.0     60
# 9   P010      F     FT    DS    -   7.0    125
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.notnull()
# Out:
#       id  gender  status   dept  var1   var2  salary
# 0   True    True    True   True  True   True   False
# 1   True    True    True   True  True  False    True
# 2   True    True    True   True  True   True    True
# 3   True    True    True   True  True   True    True
# 4   True    True    True   True  True   True    True
# 5   True    True    True  False  True  False    True
# 6   True    True    True   True  True  False   False
# 7   True    True    True   True  True   True    True
# 8   True    True    True  False  True   True    True
# 9   True    True    True   True  True   True    True
# 10  True    True   False   True  True   True   False

# %%
df.isnull()  # bu sekilde verdigi output'u anlamak zor. sonuna .sum() ile okumasi kolaylasir
# Out:
#        id  gender  status   dept   var1   var2  salary
# 0   False   False   False  False  False  False    True
# 1   False   False   False  False  False   True   False
# 2   False   False   False  False  False  False   False
# 3   False   False   False  False  False  False   False
# 4   False   False   False  False  False  False   False
# 5   False   False   False   True  False   True   False
# 6   False   False   False  False  False   True    True
# 7   False   False   False  False  False  False   False
# 8   False   False   False   True  False  False   False
# 9   False   False   False  False  False  False   False
# 10  False   False    True  False  False  False    True

# %%
df.isnull().sum()  # her column'daki null sayisi
# df.isna() ile df.isnull() ayni
# Out:
# id        0
# gender    0
# status    1
# dept      2
# var1      0
# var2      3
# salary    3
# dtype: int64

# %%
df.isnull().sum().sum()  # df'deki toplam null sayisi
# sum(df.isnull().sum()) aynisi
# Out:
# 9

# %%
df.isnull().any(axis=0)
# Out:
# id        False
# gender    False
# status     True
# dept       True
# var1      False
# var2       True
# salary     True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# dtype: bool

# %%
df.salary.isnull().any()  # salary'de null deger var mi
# Out:
# True

# %%
df.salary.isnull().sum()  # kac tane var
# Out:
# 3

# %%
df.shape
# Out:
# (11, 7)

# %%
(df.isnull().sum() / len(df)) * 100  # missing value %'si
# Out:
# id         0.000000
# gender     0.000000
# status     9.090909
# dept      18.181818
# var1       0.000000
# var2      27.272727
# salary    27.272727
# dtype: float64

# %%
df[df.isnull().any(axis=1)]  # 2, 3, 4, 7, 9 string old. icin gelmedi. # sadece '-' ve 'nan' olanlarda gelmedi
# [bir tane daha [icine alinca true, false yerine degerleri döndü]]
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.loc[~df.isnull().any(axis=1)]  # "~", islemin tam tersini yapar. missing value'su olmayanlari getirdi
# Out:
#      id gender status dept var1  var2 salary
# 2  P003      M      -  AWS    5   5.0     59
# 3  P004      F     FT  AWS  nan   8.0    120
# 4  P005      M     PT   DS    7  11.0     58
# 7  P008      F      -   FS   10   2.0    136
# 9  P010      F     FT   DS    -   7.0    125

# %%
df.loc[df.isnull().any(axis=1)]  # loc index'leme yapar. yani []. yukardakiler 'basic index''lemeydi
                                 # loc icine condition yazilabilir
# Out:
#       id gender status  dept var1  var2 salary
# 0   P001      M     FT    DS    2   8.0    NaN
# 1   P002      F     PT    FS    3   NaN     54
# 5   P006      F     PT  None    1   NaN     75
# 6   P007      M     FT    FS  nan   NaN   None
# 8   P009      M     PT   NaN   14   3.0     60
# 10  P011      M    NaN   AWS    6   9.0    NaN

# %%
df.loc[~df.isnull().any(axis=1)]
# Out:
#      id gender status dept var1  var2 salary
# 2  P003      M      -  AWS    5   5.0     59
# 3  P004      F     FT  AWS  nan   8.0    120
# 4  P005      M     PT   DS    7  11.0     58
# 7  P008      F      -   FS   10   2.0    136
# 9  P010      F     FT   DS    -   7.0    125

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Converting Inappropriate Values to NaN Values</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - map()
# - replace()

# %%
df["var1"]
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].map({"-": np.nan})  # "-" buldu NaN yapti ama digerlerini tanimlamadigim icin hepsini NaN yapti
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# Name: var1, dtype: float64

# %% [markdown]
# **Notes:** When **``arg``** parameter is a dictionary, values in Series that are NOT in the dictionary (as keys) are converted to NaN. However, if the dictionary is a dict subclass that defines __missing__ (i.e. provides a method for default values), then this default is used rather than NaN [SOURCE](https://www.w3resource.com/pandas/series/series-map.php#:~:text=The%20map()%20function%20is,a%20dict%20or%20a%20Series.&text=Mapping%20correspondence.&text=If%20'ignore'%2C%20propagate%20NaN,them%20to%20the%20mapping%20correspondence.).

# %%
df["var1"].replace(to_replace = "-", value = np.nan)
# replace: bunu, bununla degistir demek. map yerine daha iyi oldu
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9     NaN
# 10      6
# Name: var1, dtype: object

# %%
df["var1"].replace(to_replace = "-", value = np.nan).astype("float")  # to_replace ve value = default 
# astype("float") ile hepsini dtype: float64 yapti
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"]
# Out:
# 0       2
# 1       3
# 2       5
# 3     nan
# 4       7
# 5       1
# 6     nan
# 7      10
# 8      14
# 9       -
# 10      6
# Name: var1, dtype: object

# %%
df["var1"] = df["var1"].replace(to_replace = "-", value = np.nan).astype("float")
# assaign yaptim ve yukardakini artik asagidaki gibi yaptim

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df.status
# Out:
# 0      FT
# 1      PT
# 2       -
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7       -
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df['status'] = df.status.replace('-', np.nan)  # astype yapmaya gerek yok cünkü kategorik veri(numeric degil)
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df['var1'] = df['var1'].replace(to_replace = ['nan', '-'], value=np.nan).astype('float')

# %%
df.gender.map({"M": 1, "F": 0})  # unique degerleri az olan bir columnda 'map' kullanmak güzel olur. bu sekilde numerical'e gidebilirim
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# Name: gender, dtype: int64

# %%
df.isnull().sum()  # yukarda null degerler daha coktu. yapilan dönüsümlerle azaldi ve NaN'a cevrildi
# Out:
# id        0
# gender    0
# status    3
# dept      2
# var1      3
# var2      3
# salary    3
# dtype: int64

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Missing Value Handling Methods</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
#  1. <b>Deleting (Dropping) Rows</b> ----->if it has more than 70-75% of missing values
#
#  2. <b>Replacing (Filling) With Mean/Median/Mode (Imputation)</b>--->can be applied on a feature which has numeric data
#
#  3. <b> Assigning An Unique Category</b>--->If a categorical feature has definite number of classes, we can assign another class
#
#  4. <b>Predicting The Missing Values</b>---> we can predict the nulls with the help of a machine learning algorithm like linear regression
#
#  5. <b>Using Algorithms Which Support Missing Values</b>--->KNN is a machine learning algorithm which works on the principle of distance measure.  This algorithm can be used when there are nulls present in the dataset.  KNN considers the missing values by taking the majority of the K nearest values

# %% [markdown]
#  ## 1 - Dropping
#
#  - dropna()
#  - drop()

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.dropna(axis= 0,
         how = 'any',  # 'any', herhangi bir tane varsa satiri yok et
         thresh= None,
         inplace= False)
# dropna sadece missing value degerleri degistirir
# drop her seyi düsebilir
# Out:
#      id gender status dept  var1  var2 salary
# 4  P005      M     PT   DS   7.0  11.0     58

# %%
df.dropna(axis= 1,
         how = 'any',  # 'any', herhangi bir tane varsa sütunu yok et
         thresh= None,
         inplace= False)
# Out:
#       id gender
# 0   P001      M
# 1   P002      F
# 2   P003      M
# 3   P004      F
# 4   P005      M
# 5   P006      F
# 6   P007      M
# 7   P008      F
# 8   P009      M
# 9   P010      F
# 10  P011      M

# %%
df.dropna(axis= 0,
         how = 'all',  # her satir ve sütunda en az 1 tane NaN old. icin hic birini yok etmedi
         thresh= None,
         inplace= False)
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# * **``any``** : If any NA values are present, drop that row or column.
# * **``all``** : If all values are NA, drop that row or column [Source](https://www.journaldev.com/33492/pandas-dropna-drop-null-na-values-from-dataframe).

# %%
df["delete_me"] = np.nan  # na'lardan olusan sütun olusturdu
df
# Out:
#       id gender status  dept  var1  var2 salary  delete_me
# 0   P001      M     FT    DS   2.0   8.0    NaN        NaN
# 1   P002      F     PT    FS   3.0   NaN     54        NaN
# 2   P003      M    NaN   AWS   5.0   5.0     59        NaN
# 3   P004      F     FT   AWS   NaN   8.0    120        NaN
# 4   P005      M     PT    DS   7.0  11.0     58        NaN
# 5   P006      F     PT  None   1.0   NaN     75        NaN
# 6   P007      M     FT    FS   NaN   NaN   None        NaN
# 7   P008      F    NaN    FS  10.0   2.0    136        NaN
# 8   P009      M     PT   NaN  14.0   3.0     60        NaN
# 9   P010      F     FT    DS   NaN   7.0    125        NaN
# 10  P011      M    NaN   AWS   6.0   9.0    NaN        NaN

# %%
df.dropna(axis= 1,
         how = 'all',
         thresh= None,
         inplace= True)  # inplace= True ile kalici degisiklik yaparak sütunu tamamen sildi

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# **``thresh=N``** requires that a column has at least N **non-NaNs to survive.** [Source](https://stackoverflow.com/questions/51584906/thresh-in-dropna-for-dataframe-in-pandas-in-python/51584935)

# %%
df.dropna(axis= 1,
         how = 'all',
         thresh= 9,  # column'unda 9 tane NaN olmayanlari kurtar
         inplace= False)
# Out:
#       id gender  dept
# 0   P001      M    DS
# 1   P002      F    FS
# 2   P003      M   AWS
# 3   P004      F   AWS
# 4   P005      M    DS
# 5   P006      F  None
# 6   P007      M    FS
# 7   P008      F    FS
# 8   P009      M   NaN
# 9   P010      F    DS
# 10  P011      M   AWS

# %%
df.dropna(axis= 1,
         how = 'all',
         thresh= 8,  # column'unda 8 tane NaN olmayanlari kurtar
         inplace= False)
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df.drop([1, 3, 5])  # 1., 3., ve 5.rows'lari sildi
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.drop(["var1", "var2"], axis=1)  # column'dan "var1" ve "var2" silindi
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %%
df.drop(index=[1, 3, 5])  # axis kullanmadan index ile drop
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 4   P005      M     PT   DS   7.0  11.0     58
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT  NaN  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.drop(columns=["var1", "var2"])  # axis kullanmadan column ile drop
# Out:
#       id gender status  dept salary
# 0   P001      M     FT    DS    NaN
# 1   P002      F     PT    FS     54
# 2   P003      M    NaN   AWS     59
# 3   P004      F     FT   AWS    120
# 4   P005      M     PT    DS     58
# 5   P006      F     PT  None     75
# 6   P007      M     FT    FS   None
# 7   P008      F    NaN    FS    136
# 8   P009      M     PT   NaN     60
# 9   P010      F     FT    DS    125
# 10  P011      M    NaN   AWS    NaN

# %% [markdown]
#  ## 2 - Filling Missing Values (Imputation)

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
#  #### a.Filling with a specific value

# %%
df.fillna(0)
# fillna(0), tün NaN'lari 0 ile dolduruyor
# Out:
#       id gender status dept  var1  var2  salary
# 0   P001      M     FT   DS   2.0   8.0       0
# 1   P002      F     PT   FS   3.0   0.0      54
# 2   P003      M      0  AWS   5.0   5.0      59
# 3   P004      F     FT  AWS   0.0   8.0     120
# 4   P005      M     PT   DS   7.0  11.0      58
# 5   P006      F     PT    0   1.0   0.0      75
# 6   P007      M     FT   FS   0.0   0.0       0
# 7   P008      F      0   FS  10.0   2.0     136
# 8   P009      M     PT    0  14.0   3.0      60
# 9   P010      F     FT   DS   0.0   7.0     125
# 10  P011      M      0  AWS   6.0   9.0       0

# %%
df["var1"].fillna(0)  # tek bir column'a fillna
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      0.0
# 4      7.0
# 5      1.0
# 6      0.0
# 7     10.0
# 8     14.0
# 9      0.0
# 10     6.0
# Name: var1, dtype: float64

# %% [markdown]
#  #### b.Filling with any Proper Value

# %% [markdown]
# Proper Value: uygun bir veriyle doldurma.
#               ``numerical`` verilerle kullanilir

# %%
df["var1"]
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      NaN
# 4      7.0
# 5      1.0
# 6      NaN
# 7     10.0
# 8     14.0
# 9      NaN
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].mean()  # sütun mean'i
# Out:
# 6.0

# %%
df["var1"].fillna(df["var1"].mean())  # NaN'lari mean ile doldurdum
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      6.0
# 4      7.0
# 5      1.0
# 6      6.0
# 7     10.0
# 8     14.0
# 9      6.0
# 10     6.0
# Name: var1, dtype: float64

# %%
df["var1"].median()
# Out:
# 5.5

# %%
df["var1"].fillna(df["var1"].median())
# Out:
# 0      2.0
# 1      3.0
# 2      5.0
# 3      5.5
# 4      7.0
# 5      1.0
# 6      5.5
# 7     10.0
# 8     14.0
# 9      5.5
# 10     6.0
# Name: var1, dtype: float64

# %%
df.mean()
# Out:
# C:\Users\uksal\AppData\Local\Temp/ipykernel_24236/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# var1       6.000
# var2       6.625
# salary    85.875
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
# C:\Users\uksal\AppData\Local\Temp/ipykernel_24236/634187881.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.fillna(df.mean())
#       id gender status  dept  var1    var2   salary
# 0   P001      M     FT    DS   2.0   8.000   85.875
# 1   P002      F     PT    FS   3.0   6.625   54.000
# 2   P003      M    NaN   AWS   5.0   5.000   59.000
# 3   P004      F     FT   AWS   6.0   8.000  120.000
# 4   P005      M     PT    DS   7.0  11.000   58.000
# 5   P006      F     PT  None   1.0   6.625   75.000
# 6   P007      M     FT    FS   6.0   6.625   85.875
# 7   P008      F    NaN    FS  10.0   2.000  136.000
# 8   P009      M     PT   NaN  14.0   3.000   60.000
# 9   P010      F     FT    DS   6.0   7.000  125.000
# 10  P011      M    NaN   AWS   6.0   9.000   85.875

# %%
df.fillna({"dept": "other", "var1": df.var1.mean(), "var2": df.var2.median()})
# her column'a ayri atama yaptim
# Out:
#       id gender status   dept  var1  var2 salary
# 0   P001      M     FT     DS   2.0   8.0    NaN
# 1   P002      F     PT     FS   3.0   7.5     54
# 2   P003      M    NaN    AWS   5.0   5.0     59
# 3   P004      F     FT    AWS   6.0   8.0    120
# 4   P005      M     PT     DS   7.0  11.0     58
# 5   P006      F     PT  other   1.0   7.5     75
# 6   P007      M     FT     FS   6.0   7.5   None
# 7   P008      F    NaN     FS  10.0   2.0    136
# 8   P009      M     PT  other  14.0   3.0     60
# 9   P010      F     FT     DS   6.0   7.0    125
# 10  P011      M    NaN    AWS   6.0   9.0    NaN

# %% [markdown]
# **where() Replace values where the condition is** **``False``**.

# %%
df.notna()  # notna ile hangisi MissingValue degildir diye sorulur. True/False dönüyor. False dönenler 'na' degerlerdir
# where, False üzerine odaklanir
# Out:
#       id  gender  status   dept   var1   var2  salary
# 0   True    True    True   True   True   True   False
# 1   True    True    True   True   True  False    True
# 2   True    True   False   True   True   True    True
# 3   True    True    True   True  False   True    True
# 4   True    True    True   True   True   True    True
# 5   True    True    True  False   True  False    True
# 6   True    True    True   True  False  False   False
# 7   True    True   False   True   True   True    True
# 8   True    True    True  False   True   True    True
# 9   True    True    True   True  False   True    True
# 10  True    True   False   True   True   True   False

# %%
df.where(cond=df.notna(), other=df.mean(), axis= 1)
# where, False üzerine odaklanir. False olanlari "other=df.'mean'()" ile doldur kodu
# Out:
# C:\Users\uksal\AppData\Local\Temp/ipykernel_24236/3416091625.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.where(cond=df.notna(), other=df.mean(), axis= 1)
#       id gender status dept  var1    var2  salary
# 0   P001      M     FT   DS   2.0   8.000  85.875
# 1   P002      F     PT   FS   3.0   6.625      54
# 2   P003      M    NaN  AWS   5.0   5.000      59
# 3   P004      F     FT  AWS   6.0   8.000     120
# 4   P005      M     PT   DS   7.0  11.000      58
# 5   P006      F     PT  NaN   1.0   6.625      75
# 6   P007      M     FT   FS   6.0   6.625  85.875
# 7   P008      F    NaN   FS  10.0   2.000     136
# 8   P009      M     PT  NaN  14.0   3.000      60
# 9   P010      F     FT   DS   6.0   7.000     125
# 10  P011      M    NaN  AWS   6.0   9.000  85.875

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# **Fill NaN values using an interpolation method.**

# %%
df.interpolate()  # bos degerleri altindaki ve üstündekinin ortalamasi ile doldurdu.
# 1 den dazla bosluk varsa : 11 ve 2 arasinda 2 bosluk var => 11-2=9 --> 9/3=3 --> 2-5-8-11
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   6.5     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   6.0   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   8.0     75
# 6   P007      M     FT    FS   5.5   5.0   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS  10.0   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %% [markdown]
# For more information about [interpolation](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/)

# %% [markdown]
#  #### c.Filling the Missing Values of ``#Categorical`` Variables

# %%
df
# Out:
#       id gender status  dept  var1  var2 salary
# 0   P001      M     FT    DS   2.0   8.0    NaN
# 1   P002      F     PT    FS   3.0   NaN     54
# 2   P003      M    NaN   AWS   5.0   5.0     59
# 3   P004      F     FT   AWS   NaN   8.0    120
# 4   P005      M     PT    DS   7.0  11.0     58
# 5   P006      F     PT  None   1.0   NaN     75
# 6   P007      M     FT    FS   NaN   NaN   None
# 7   P008      F    NaN    FS  10.0   2.0    136
# 8   P009      M     PT   NaN  14.0   3.0     60
# 9   P010      F     FT    DS   NaN   7.0    125
# 10  P011      M    NaN   AWS   6.0   9.0    NaN

# %%
df["dept"].mode()  # hepsinden 3'er tane olunca birden cok 'mode' oldu. Genelde 0. secilir
# Out:
# 0    AWS
# 1     DS
# 2     FS
# dtype: object

# %%
df["dept"].mode()[0]
# Out:
# 'AWS'

# %%
df["dept"].fillna(df["dept"].mode()[0])  # "dept" column'unda 'None'lari mode[0] ile doldurdu
# Out:
# 0      DS
# 1      FS
# 2     AWS
# 3     AWS
# 4      DS
# 5     AWS
# 6      FS
# 7      FS
# 8     AWS
# 9      DS
# 10    AWS
# Name: dept, dtype: object

# %%
df["status"].fillna(method= "ffill")  # pad / ffill kendinden önceki ile doldurur
# Out:
# 0     FT
# 1     PT
# 2     PT
# 3     FT
# 4     PT
# 5     PT
# 6     FT
# 7     FT
# 8     PT
# 9     FT
# 10    FT
# Name: status, dtype: object

# %%
df["status"].fillna(method= "bfill")  # backfill / bfill kendinden sonraki ile doldurur. *10.dan sonra 11 olmadigi icin dolduramadi
# Out:
# 0      FT
# 1      PT
# 2      FT
# 3      FT
# 4      PT
# 5      PT
# 6      FT
# 7      PT
# 8      PT
# 9      FT
# 10    NaN
# Name: status, dtype: object

# %%
df["status"].fillna(method= "bfill").fillna(method= "ffill")  # varsa kendinden sonraki ile yoksa önceki ile doldur. böylece bosta kalan olmaz
# Out:
# 0     FT
# 1     PT
# 2     FT
# 3     FT
# 4     PT
# 5     PT
# 6     FT
# 7     PT
# 8     PT
# 9     FT
# 10    FT
# Name: status, dtype: object

# %% [markdown]
# - **pad / ffill:** propagate last valid observation forward to next valid
# - **backfill / bfill:** use next valid observation to fill gap.

# %% [markdown]
#  #### d.Filling by condition & by Group of the Categorical Variables

# %%
df["dept"].fillna(method= "ffill", inplace= True)  # 'inplace= True' ile 'dept' column'u yapilan degisikliklerle kaydettim
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the missing values at "status" column with defined condition by "salary"**

# %%
df[df["salary"] > 100]
# Out:
#      id gender status dept  var1  var2 salary
# 3  P004      F     FT  AWS   NaN   8.0    120
# 7  P008      F    NaN   FS  10.0   2.0    136
# 9  P010      F     FT   DS   NaN   7.0    125

# %%
df.loc[df["salary"] > 100, "status"]  # 100'den fazla kazananlarin FT, PT 'Status'e baktim. Hepsi FullTime
# Out:
# 3     FT
# 7    NaN
# 9     FT
# Name: status, dtype: object

# %%
df.loc[df["salary"] < 100, "status"]  # 100'den az kazananlarin FT, PT 'Status'e baktim. Hepsi PartTime
# Out:
# 1     PT
# 2    NaN
# 4     PT
# 5     PT
# 8     PT
# Name: status, dtype: object

# %%
df.loc[df["salary"]>=100, "status"].fillna(df.loc[df["salary"]>=100, "status"].mode()[0], inplace=True)
df.loc[df["salary"]<100, "status"].fillna(df.loc[df["salary"]<100, "status"].mode()[0], inplace=True)
df

# inplace=True, loc icinde calismiyor !!!
# loc metod degil, indexing
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M    NaN  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F    NaN   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df.loc[df["salary"] >= 100, "status"] = df.loc[df["salary"] >= 100, "status"].fillna(df.loc[df["salary"] >= 100, "status"].mode()[0])
# kazanci 100den büyük olup Status'ü None olanlari 100den cok kazanalarin mod[0]yla doldur
df.loc[df["salary"] < 100, "status"] = df.loc[df["salary"] < 100, "status"].fillna(df.loc[df["salary"] < 100, "status"].mode()[0])
# kazanci 100den az olup Status'ü None olanlari 100den az kazanalarin mod[0]yla doldur
df
# 10. rows'da Salary olmadigi icin dolduramadi
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the last missing value at "status" column with the mode of the group of "gender" and "dept"**

# %%
df
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M    NaN  AWS   6.0   9.0    NaN

# %%
df[["gender", "status", "dept"]]  # catagoric olanlar
# Out:
#    gender status dept
# 0       M     FT   DS
# 1       F     PT   FS
# 2       M     PT  AWS
# 3       F     FT  AWS
# 4       M     PT   DS
# 5       F     PT   DS
# 6       M     FT   FS
# 7       F     FT   FS
# 8       M     PT   FS
# 9       F     FT   DS
# 10      M    NaN  AWS

# %%
df.groupby(["gender", "dept"])["status"]  # lazy object olarak geldi

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x: x.mode())  # eöementweise olarak calisti
# Out:
# gender  dept
# F       AWS   0    FT
#         DS    0    FT
#               1    PT
#         FS    0    FT
#               1    PT
# M       AWS   0    PT
#         DS    0    FT
#               1    PT
#         FS    0    FT
#               1    PT
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].agg(lambda x: pd.Series.mode(x))
# Out:
# gender  dept
# F       AWS           FT
#         DS      [FT, PT]
#         FS      [FT, PT]
# M       AWS           PT
#         DS      [FT, PT]
#         FS      [FT, PT]
# Name: status, dtype: object

# %%
df.groupby(["gender", "dept"])["status"].apply(lambda x: x.mode()).index
# multi index oldugunu gösterdi
# Out:
# MultiIndex([('F', 'AWS', 0),
#             ('F',  'DS', 0),
#             ('F',  'DS', 1),
#             ('F',  'FS', 0),
#             ('F',  'FS', 1),
#             ('M', 'AWS', 0),
#             ('M',  'DS', 0),
#             ('M',  'DS', 1),
#             ('M',  'FS', 0),
#             ('M',  'FS', 1)],
#            names=['gender', 'dept', None])

# %%
df.groupby(["gender", "dept"], as_index=True)["status"].apply(lambda x: pd.Series.mode(x)[0])
# multi index olarak döndü
# Out:
# gender  dept
# F       AWS     FT
#         DS      FT
#         FS      FT
# M       AWS     PT
#         DS      FT
#         FS      FT
# Name: status, dtype: object

# %%
# df.groupby(["gender", "dept"], as_index=True)["status"].apply(lambda x: pd.Series.mode(x)[0]).reset_index(drop=True)
# üstteki kod hata verseydi bunu calistiracaktim

# %%
df.groupby(["gender", "dept"], as_index=True)["status"].transform(lambda x: pd.Series.mode(x)[0])
# yukardaki 'apply' ile calistirdigimi 'transform' ile calistirdim, input kadar output verdi
# Out:
# 0     FT
# 1     FT
# 2     PT
# 3     FT
# 4     FT
# 5     FT
# 6     FT
# 7     FT
# 8     FT
# 9     FT
# 10    PT
# Name: status, dtype: object

# %%
df["status"].fillna(df.groupby(["gender", "dept"], as_index=True)["status"].transform(lambda x: pd.Series.mode(x)[0]), inplace=True)
# yukardakini de status'e fillna ile atadim ve inplace=True ile degisiklikleri kaydetti

# %%
df
# status'de None olan 11. satirda doldu
# Out:
#       id gender status dept  var1  var2 salary
# 0   P001      M     FT   DS   2.0   8.0    NaN
# 1   P002      F     PT   FS   3.0   NaN     54
# 2   P003      M     PT  AWS   5.0   5.0     59
# 3   P004      F     FT  AWS   NaN   8.0    120
# 4   P005      M     PT   DS   7.0  11.0     58
# 5   P006      F     PT   DS   1.0   NaN     75
# 6   P007      M     FT   FS   NaN   NaN   None
# 7   P008      F     FT   FS  10.0   2.0    136
# 8   P009      M     PT   FS  14.0   3.0     60
# 9   P010      F     FT   DS   NaN   7.0    125
# 10  P011      M     PT  AWS   6.0   9.0    NaN

# %% [markdown]
# **Let's fill the missing values at "salary" column with the mean of the group of "status" and "dept"**

# %%
df.groupby("dept")["salary"].mean()  # dept'e göre salary icin mean verdi
# Out:
# dept
# AWS    89.500000
# DS     86.000000
# FS     83.333333
# Name: salary, dtype: float64

# %%
df.groupby(["status", "dept"])["salary"].mean()  # hem "status"e hem de "dept"e göre salary icin mean verdi
# Out:
# status  dept
# FT      AWS     120.0
#         DS      125.0
#         FS      136.0
# PT      AWS      59.0
#         DS       66.5
#         FS       57.0
# Name: salary, dtype: float64

# %%
df.salary  # böyleydi altta doldurdum
# Out:
# 0      NaN
# 1       54
# 2       59
# 3      120
# 4       58
# 5       75
# 6     None
# 7      136
# 8       60
# 9      125
# 10     NaN
# Name: salary, dtype: object

# %%
df.groupby(["status", "dept"])["salary"].transform("mean")  # yukardaki ciktiya mean'e göre transform uyguladi
# Out:
# 0     125.0
# 1      57.0
# 2      59.0
# 3     120.0
# 4      66.5
# 5      66.5
# 6     136.0
# 7     136.0
# 8      57.0
# 9     125.0
# 10     59.0
# Name: salary, dtype: float64

# %%
df["trans_salary"] = df.groupby(["status", "dept"])["salary"].transform("mean")
# check etmek icin "trans_salary" column'u olusturdum
df
# Out:
#       id gender status dept  var1  var2 salary  trans_salary
# 0   P001      M     FT   DS   2.0   8.0    NaN         125.0
# 1   P002      F     PT   FS   3.0   NaN     54          57.0
# 2   P003      M     PT  AWS   5.0   5.0     59          59.0
# 3   P004      F     FT  AWS   NaN   8.0    120         120.0
# 4   P005      M     PT   DS   7.0  11.0     58          66.5
# 5   P006      F     PT   DS   1.0   NaN     75          66.5
# 6   P007      M     FT   FS   NaN   NaN   None         136.0
# 7   P008      F     FT   FS  10.0   2.0    136         136.0
# 8   P009      M     PT   FS  14.0   3.0     60          57.0
# 9   P010      F     FT   DS   NaN   7.0    125         125.0
# 10  P011      M     PT  AWS   6.0   9.0    NaN          59.0

# %%
df["salary"].fillna(df.groupby(["status", "dept"])["salary"].transform("mean"), inplace=True)
# yukardaki atamayi inplace=True ile kaydetti
df
# Out:
#       id gender status dept  var1  var2  salary  trans_salary
# 0   P001      M     FT   DS   2.0   8.0   125.0         125.0
# 1   P002      F     PT   FS   3.0   NaN    54.0          57.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0          59.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0         120.0
# 4   P005      M     PT   DS   7.0  11.0    58.0          66.5
# 5   P006      F     PT   DS   1.0   NaN    75.0          66.5
# 6   P007      M     FT   FS   NaN   NaN   136.0         136.0
# 7   P008      F     FT   FS  10.0   2.0   136.0         136.0
# 8   P009      M     PT   FS  14.0   3.0    60.0          57.0
# 9   P010      F     FT   DS   NaN   7.0   125.0         125.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0          59.0

# %% [markdown]
# **Let's fill the missing values at "var1" column with the mean of the group of "gender" and "status"**

# %%
df.groupby(["gender", "status"])["var1"]  # lazy object

# %%
df.groupby(["gender", "status"])["var1"].mean()  # agg. fonksiyon ile actim
# Out:
# gender  status
# F       FT        10.0
#         PT         2.0
# M       FT         2.0
#         PT         8.0
# Name: var1, dtype: float64

# %%
df.groupby(["gender", "status"])["var1"].transform("mean")
# Out:
# 0      2.0
# 1      2.0
# 2      8.0
# 3     10.0
# 4      8.0
# 5      2.0
# 6      2.0
# 7     10.0
# 8      8.0
# 9     10.0
# 10     8.0
# Name: var1, dtype: float64

# %%
df["trans_var1"] = df.groupby(["gender", "status"])["var1"].transform("mean")
# cross check icin yani column eklendi
df
# Out:
#       id gender status dept  var1  var2  salary  trans_salary  trans_var1
# 0   P001      M     FT   DS   2.0   8.0   125.0         125.0         2.0
# 1   P002      F     PT   FS   3.0   NaN    54.0          57.0         2.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0          59.0         8.0
# 3   P004      F     FT  AWS   NaN   8.0   120.0         120.0        10.0
# 4   P005      M     PT   DS   7.0  11.0    58.0          66.5         8.0
# 5   P006      F     PT   DS   1.0   NaN    75.0          66.5         2.0
# 6   P007      M     FT   FS   NaN   NaN   136.0         136.0         2.0
# 7   P008      F     FT   FS  10.0   2.0   136.0         136.0        10.0
# 8   P009      M     PT   FS  14.0   3.0    60.0          57.0         8.0
# 9   P010      F     FT   DS   NaN   7.0   125.0         125.0        10.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0          59.0         8.0

# %%
trans_var1 = df.groupby(["gender", "status"])["var1"].transform("mean")

# %%
df["var1"].fillna(trans_var1, inplace=True)
# var1 deki missingvalue'leri  fillna ile yukarda yazilan kod ile degisiklikleri kaydedecek sekilde dolduruyorum

# %%
df
# var1 ve salary doldu, var2 kaldi
# Out:
#       id gender status dept  var1  var2  salary  trans_salary  trans_var1
# 0   P001      M     FT   DS   2.0   8.0   125.0         125.0         2.0
# 1   P002      F     PT   FS   3.0   NaN    54.0          57.0         2.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0          59.0         8.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0         120.0        10.0
# 4   P005      M     PT   DS   7.0  11.0    58.0          66.5         8.0
# 5   P006      F     PT   DS   1.0   NaN    75.0          66.5         2.0
# 6   P007      M     FT   FS   2.0   NaN   136.0         136.0         2.0
# 7   P008      F     FT   FS  10.0   2.0   136.0         136.0        10.0
# 8   P009      M     PT   FS  14.0   3.0    60.0          57.0         8.0
# 9   P010      F     FT   DS  10.0   7.0   125.0         125.0        10.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0          59.0         8.0

# %% [markdown]
# **Let's fill the missing values at "var2" column with the mean of group of "status"**

# %%
df["var2"]
# Out:
# 0      8.0
# 1      NaN
# 2      5.0
# 3      8.0
# 4     11.0
# 5      NaN
# 6      NaN
# 7      2.0
# 8      3.0
# 9      7.0
# 10     9.0
# Name: var2, dtype: float64

# %%
df.groupby("gender")["var2"].mean()
# Out:
# gender
# F    5.666667
# M    7.200000
# Name: var2, dtype: float64

# %%
df.groupby(["gender", "status"])["var2"].mean()
# üstteki icin daha detayli bakmak istedim. NaN gelen yer zaten doldurmak istedigim kisim
# Out:
# gender  status
# F       FT        5.666667
#         PT             NaN
# M       FT        8.000000
#         PT        7.000000
# Name: var2, dtype: float64

# %%
df.groupby(["gender", "status"])["var2"].transform("mean")
# atayabilecek bir mean bulamadi
# Out:
# 0     8.000000
# 1          NaN
# 2     7.000000
# 3     5.666667
# 4     7.000000
# 5          NaN
# 6     8.000000
# 7     5.666667
# 8     7.000000
# 9     5.666667
# 10    7.000000
# Name: var2, dtype: float64

# %%
df.groupby(["status"])["var2"].transform("mean")
# bu oldu
# Out:
# 0     6.25
# 1     7.00
# 2     7.00
# 3     6.25
# 4     7.00
# 5     7.00
# 6     6.25
# 7     6.25
# 8     7.00
# 9     6.25
# 10    7.00
# Name: var2, dtype: float64

# %%
df["trans_var2"] = df.groupby(["status"])["var2"].transform("mean")
df
# var2'deki 1, 5, 6yi trans_var2 ile dolduracagim
# Out:
#       id gender status dept  var1  var2  salary  trans_salary  trans_var1  \
# 0   P001      M     FT   DS   2.0   8.0   125.0         125.0         2.0
# 1   P002      F     PT   FS   3.0   NaN    54.0          57.0         2.0
# 2   P003      M     PT  AWS   5.0   5.0    59.0          59.0         8.0
# 3   P004      F     FT  AWS  10.0   8.0   120.0         120.0        10.0
# 4   P005      M     PT   DS   7.0  11.0    58.0          66.5         8.0
# 5   P006      F     PT   DS   1.0   NaN    75.0          66.5         2.0
# 6   P007      M     FT   FS   2.0   NaN   136.0         136.0         2.0
# 7   P008      F     FT   FS  10.0   2.0   136.0         136.0        10.0
# 8   P009      M     PT   FS  14.0   3.0    60.0          57.0         8.0
# 9   P010      F     FT   DS  10.0   7.0   125.0         125.0        10.0
# 10  P011      M     PT  AWS   6.0   9.0    59.0          59.0         8.0
#
#     trans_var2
# 0         6.25
# 1         7.00
# 2         7.00
# ...

# %%
df["var2"].fillna(df.groupby(["status"])["var2"].transform("mean"))
# Out:
# 0      8.00
# 1      7.00
# 2      5.00
# 3      8.00
# 4     11.00
# 5      7.00
# 6      6.25
# 7      2.00
# 8      3.00
# 9      7.00
# 10     9.00
# Name: var2, dtype: float64

# %%
df["var2"] = df["var2"].fillna(df.groupby(["status"])["var2"].transform("mean"))
df
# var1 icin inplace=True ile yapmistim var2 icin atama ile yaptim
# Out:
#       id gender status dept  var1   var2  salary  trans_salary  trans_var1  \
# 0   P001      M     FT   DS   2.0   8.00   125.0         125.0         2.0
# 1   P002      F     PT   FS   3.0   7.00    54.0          57.0         2.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0          59.0         8.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0         120.0        10.0
# 4   P005      M     PT   DS   7.0  11.00    58.0          66.5         8.0
# 5   P006      F     PT   DS   1.0   7.00    75.0          66.5         2.0
# 6   P007      M     FT   FS   2.0   6.25   136.0         136.0         2.0
# 7   P008      F     FT   FS  10.0   2.00   136.0         136.0        10.0
# 8   P009      M     PT   FS  14.0   3.00    60.0          57.0         8.0
# 9   P010      F     FT   DS  10.0   7.00   125.0         125.0        10.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0          59.0         8.0
#
#     trans_var2
# 0         6.25
# 1         7.00
# 2         7.00
# ...

# %%
df.columns
# Out:
# Index(['id', 'gender', 'status', 'dept', 'var1', 'var2', 'salary',
#        'trans_salary', 'trans_var1', 'trans_var2'],
#       dtype='object')

# %%
df.drop(['trans_salary', 'trans_var1', 'trans_var2'], axis=1, inplace=True)
# None olmadan son halini aldi
# df.drop bir daha calistirilirsa hata verir, inplace=True yapinca sildi gitti

# %%
df
# Out:
#       id gender status dept  var1   var2  salary
# 0   P001      M     FT   DS   2.0   8.00   125.0
# 1   P002      F     PT   FS   3.0   7.00    54.0
# 2   P003      M     PT  AWS   5.0   5.00    59.0
# 3   P004      F     FT  AWS  10.0   8.00   120.0
# 4   P005      M     PT   DS   7.0  11.00    58.0
# 5   P006      F     PT   DS   1.0   7.00    75.0
# 6   P007      M     FT   FS   2.0   6.25   136.0
# 7   P008      F     FT   FS  10.0   2.00   136.0
# 8   P009      M     PT   FS  14.0   3.00    60.0
# 9   P010      F     FT   DS  10.0   7.00   125.0
# 10  P011      M     PT  AWS   6.0   9.00    59.0

# %% [markdown]
# ## filling with Interpolation
#
# Pandas **``dataframe.interpolate()``** function is basically used to fill NA values in the dataframe or series. But, this is a very powerful function to fill the missing values. It uses various interpolation technique to fill the missing values rather than hard-coding the value [Source 01](https://www.geeksforgeeks.org/python-pandas-dataframe-interpolate/) & [Source 02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html)

# %%
sns.get_dataset_names()
# pandas'da hazir bulunan DataSet'ler
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.isnull().sum()
# null degerim yok
# Out:
# year          0
# month         0
# passengers    0
# dtype: int64

# %%
flights.passengers.plot()  # output'da cikan <AxesSubplot:>'u görmek istemezsem kodun sonuna (;)
# Out:
# <AxesSubplot:>

# %%
flights_copy = flights.copy()
flights_copy
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_copy.loc[np.random.randint(1, 144, 20), "passengers"] = None

# %%
flights_copy.isnull().sum()
# Out:
# year           0
# month          0
# passengers    20
# dtype: int64

# %%
flights_copy.passengers.plot();  # ; yerine plot.show() kullanilabilir
# random olarak gelen None yerlerde bosluk olustu

# %%
flights_copy["passengers"].interpolate()
# Out:
# 0      112.0
# 1      118.0
# 2      123.5
# 3      129.0
# 4      121.0
#        ...
# 139    606.0
# 140    508.0
# 141    461.0
# 142    390.0
# 143    432.0
# Name: passengers, Length: 144, dtype: float64

# %%
flights_copy["passengers"].interpolate().isnull().sum()
# Out:
# 0

# %%
flights_copy["passengers"].interpolate().plot();
# missingValue'lar interpolate ile dolduruldu

# %% [markdown]
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:150%; text-align:center; border-radius:10px 10px;">The End of The Session - 07</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %% [markdown]
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# ________
