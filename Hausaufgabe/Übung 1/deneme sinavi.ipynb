# %%
import pandas as pd
import numpy as np

# %%
sales = pd.read_csv('sales_082020.csv')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
sales
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
saless = pd.read_csv('currency_rates_082020_EUR.csv')

# %%
saless
# Out:
#     currency       date    rate
# 0        EUR   8/1/2020  1.0000
# 1        EUR   8/2/2020  1.0000
# 2        EUR   8/3/2020  1.0000
# 3        EUR   8/4/2020  1.0000
# 4        EUR   8/5/2020  1.0000
# ..       ...        ...     ...
# 215      BRL   8/6/2020  6.3324
# 216      BRL   8/7/2020  6.4111
# 217      BRL   8/8/2020  6.4111
# 218      BRL   8/9/2020  6.4111
# 219      BRL  8/10/2020  6.4351
#
# [220 rows x 3 columns]

# %%
# Soru 3
sales.groupby("seller_id").count()
# Out:
#            buyer_id  buyer_country  seller_country  product_code  category  \
# seller_id
# 00026zrn          1              1               1             1         1
# 000aaqnz          1              1               1             1         1
# 0011guej          1              1               1             1         1
# 00185ns7          1              1               1             1         1
# 001r1gvf          1              1               1             1         1
# ...             ...            ...             ...           ...       ...
# zzy962vt          2              2               2             2         2
# zzy993vl          1              1               1             1         1
# zzythjtn          3              3               3             3         3
# zzzqa0ik          1              1               1             1         1
# zzzzlrla          1              1               1             1         1
#
#            brand  currency  price  date
# seller_id
# ...

# %%
# soru 8
sales[(sales.buyer_country == "AU") & (sales.category == "Shoes")].count()
# Out:
# buyer_id          658
# buyer_country     658
# seller_id         658
# seller_country    658
# product_code      658
# category          658
# brand              81
# currency          658
# price             658
# date              658
# dtype: int64

# %%
# soru 9
sales.groupby("brand").mean()["price"].sort_values(ascending=False)
# Out:
# brand
# Goyard                    339.363333
# Loewe                     302.043333
# Loeffler Randall          244.840000
# Craig Green               239.940000
# Walter Van Beirendonck    216.180000
#                              ...
# MUA                         4.686667
# Max Factor                  3.911667
# Bronica                     3.786000
# 36572                       1.120000
# 360 Cashmere                1.120000
# Name: price, Length: 1134, dtype: float64

# %%
sales[(sales.buyer_country == "GB") & (sales.seller_country == "GB")].price.count()
# Out:
# 133876

# %%
(sales.buyer_country("US").count()) / (sales.seller_country("US").count())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13432/2758687684.py in <module>
# ----> 1 (sales.buyer_country("US").count()) / (sales.seller_country("US").count())
#
# TypeError: 'Series' object is not callable

# %%
sales.price.sum()
# Out:
# 6739727.730000001

# %%
saless.groupby("currency").count()
# Out:
#           date  rate
# currency
# AUD         10    10
# BRL         10    10
# CAD         10    10
# CHF         10    10
# CZK         10    10
# DKK         10    10
# EUR         10    10
# GBP         10    10
# HKD         10    10
# HUF         10    10
# ILS         10    10
# JPY         10    10
# MXN         10    10
# MYR         10    10
# NOK         10    10
# NZD         10    10
# PLN         10    10
# SEK         10    10
# SGD         10    10
# THB         10    10
# TWD         10    10
# USD         10    10

# %%
sales.columns
# Out:
# Index(['buyer_id', 'buyer_country', 'seller_id', 'seller_country',
#        'product_code', 'category', 'brand', 'currency', 'price', 'date'],
#       dtype='object')

# %%
sales.groupby("seller_country").count()
# Out:
#                 buyer_id  buyer_country  seller_id  product_code  category  \
# seller_country
# AU                  7592           7592       7592          7592      7592
# CA                  1971           1971       1971          1971      1970
# DE                   135            135        135           135       135
# FR                    53             53         53            53        53
# GB                139203         139203     139203        139203    139195
# IE                  3014           3014       3014          3014      3013
# IT                  2464           2464       2464          2464      2464
# RoW                 1128           1128       1128          1128      1128
# US                 82111          82111      82111         82111     82105
#
#                 brand  currency   price    date
# seller_country
# AU                 63      7592    7592    7592
# CA                 21      1971    1971    1971
# ...
