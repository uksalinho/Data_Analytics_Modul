# %% [markdown]
# ___
#
# <a href="https://github.com/clarusway/DS-EU-1222-DA-Module-Students/blob/main/3-Classes%20Labs/2-DAwPY/Assignment_02_Solution.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a><br/>
# [![nbviewer](https://raw.githubusercontent.com/jupyter/design/master/logos/Badges/nbviewer_badge.svg)](https://github.com/clarusway/DS-EU-1222-DA-Module-Students/blob/main/3-Classes%20Labs/2-DAwPY/Assignment_02_Solution.ipynb)
# ___
#
# <a href="https://clarusway.com/"><img align="center" src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" alt="CLRSWY" title="Open and Execute in Google Colaboratory"></a><br/>
#
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:120%; text-align:center; border-radius:10px 10px;">Way to Reinvent Yourself</p>
#
# <p style="text-align: center;"><img src="https://i.ibb.co/99DQ3TY/DS-Courses.png" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">Data Analysis with Python</p>
#
# ![Image_Assignment](https://i.ibb.co/cY9HhF7/bnote-assignment.gif)
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#4d77cf; font-size:200%; text-align:center; border-radius:10px 10px;">Assignment 02 (Pandas)</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTENT</p>
#
#
# * [CONTEXT](#0)
# * [ABOUT THE DATASET & ATRIBUTES](#00)
# * [INSTRUCTIONS (Tasks in the Assignment)](#000)
# * [IMPORTING LIBRARIES NEEDED IN THIS NOTEBOOK](#1)
# * [Task 01. Checking the head of the DataFrame](#2)
# * [Task 02. How many rows and columns are there?](#3)
# * [Task 03. What is the average Purchase Price?](#4)
# * [Task 04. What were the highest and lowest purchase prices?](#5)
# * [Task 05. Listing the country names and number of records belongs to each country](#6)
# * [Task 06. How many records are as Country United Kingdom?](#7)
# * [Task 07. Creating a column named Total which shows the total amount of spend using UnitPrice and Quantity](#8)
# * [Task 08. Showing total spending amount according to the Countries](#9)
# * [Task 09. Which Country spend least?](#10)
# * [Task 10. Calculating average of spending according to country with apply function](#11)
# * [Task 11. Calculating average, mean, max of spending according to country with agg function](#12)
# * [Task 12. What is the max Total spending in whole dataset and show the records of that spending?](#13)
# * [Task 13. How many people who live in Spain spend more than average Total?](#14)
# * [Task 14. Converting datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2](#15)
# * [Task 15. Taking only date values (year-month-day) from InvoiceDate2 and assign it to a new column named "date"](#16)
# * [Task 16. Dropping InvoiceDate2 and InvoiceDate columns permanently](#17)
# * [Task 17. Removing A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method](#18)
# * [Task 18. Taking only Total and date columns with loc and craete a new df named ecom2](#19)
# * [Task 19. Taking only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3](#20)
# * [Task 20. Combining ecom2 and ecom3 with concat() method](#21)
# * [Task 21. Combining the common (intersected) values of ecom2 and ecom3 with merge() method](#22)
# * [Task 22. Combining ecom2 and ecom3 with join() method](#23)
# * [THE END OF THE ASSIGNMENT 02](#24)

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">CONTEXT</p>
#
# <a id="0"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# E-Commerce is currently one of the fastest and dynamically evolving industries in the world. Its popularity has been growing rapidly with the ease of digital transactions and quick door-to-door deliveries. A major source of big tech companies revenues comes from the interaction of their underlying proprietary algorithms that are heavily powered by data science, so it’s fundamental to understand the methods applied to maintain and grow the number of clients.
#
# "This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers."

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE DATASET & ATRIBUTES</p>
#
# <a id="00"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Typically e-commerce datasets are proprietary and consequently hard to find among publicly available data. However, The [UCI Machine Learning Repository](http://archive.ics.uci.edu/ml/index.php) has made this dataset containing actual transactions from 2010 and 2011. The dataset is maintained on their site, where it can be found by the title "Online Retail".
#
# **Attribute Information:**
#
# **``InvoiceNo:``** Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.<br>
# **``StockCode:``** Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.<br>
# **``Description:``** Product (item) name. Nominal.<br>
# **``Quantity:``** The quantities of each product (item) per transaction. Numeric.<br>
# **``InvoiceDate:``** Invice Date and time. Numeric, the day and time when each transaction was generated.<br>
# **``UnitPrice:``** Unit price. Numeric, Product price per unit in sterling.<br>
# **``CustomerID:``** Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.<br>
# **``Country:``** Country name. Nominal, the name of the country where each customer resides.<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">INSTRUCTIONS (Tasks in the Assignment)</p>
#
# <a id="000"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **In this assignment you're required to handle with the following tasks:**
#
# - **Task 01.** Checking the head of the DataFrame.<br>
# - **Task 02.** How many rows and columns are there?<br>
# - **Task 03.** What is the average of Product sold and the average price of Product per unit?<br>
# - **Task 04.** What were the highest and lowest purchase prices?<br>
# - **Task 05.** Listing the country names and number of their records belongs to each country.<br>
# - **Task 06.** How many records are as Country United Kingdom?<br>
# - **Task 07.** Creating a column named Total which shows the total amount of spend using UnitPrice and Quantity.<br>
# - **Task 08.** Showing total spending amount according to the Countries.<br>
# - **Task 09.** Which Country spend least?<br>
# - **Task 10.** Calculate the average of spending according to country with apply function and create a new feature named "Average_Spend".<br>
# - **Task 11.** Calculating average, min, max of spending according to country with agg function and create new features named "Max_Spend" and "Min_Spend".<br>
# - **Task 12.** What is the max Total spending in whole dataset and show all records of that spending?<br>
# - **Task 13.** How many people who live in Spain spend more than average Total?<br>
# - **Task 14.** Converting datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2.<br>
# - **Task 15.** Taking only date values (year-month-day) from InvoiceDate2 and assign it to a new column named "date".<br>
# - **Task 16.** Dropping InvoiceDate2 and InvoiceDate columns permanently.<br>
# - **Task 17.** Removing A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method.<br>
# - **Task 18.** Taking only Total and date columns with loc and craete a new df named ecom2.<br>
# - **Task 19.** Taking only InvoiceNo and CustomerID columns with iloc and craete a new df named ecom3.<br>
# - **Task 20.** Combining ecom2 and ecom3 with concat() method.<br>
# - **Task 21.** Combining the common (intersected) values of ecom2 and ecom3 with merge() method.<br>
# - **Task 22.** Combining ecom2 and ecom3 with join() method.<br>

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">How to Install/Enable Intellisense or Autocomplete in Jupyter Notebook</p>
#
# ### Installing [jupyter_contrib_nbextensions](https://jupyter-contrib-nbextensions.readthedocs.io/en/latest/install.html)
#
# **To install the current version from The Python Package Index (PyPI), which is a repository of software for the Python programming language, simply type:**
#
# !pip install jupyter_contrib_nbextensions
#
# **Alternatively, you can install directly from the current master branch of the repository:**
#
# !pip install https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tarball/master
#
# ### Enabling [Intellisense or Autocomplete in Jupyter Notebook](https://botbark.com/2019/12/18/how-to-enable-intellisense-or-autocomplete-in-jupyter-notebook/)
#
#
# ### Installing hinterland for jupyter without anaconda
#
# **``STEP 1:``** ``Open cmd prompt and run the following commands``
#  1) pip install jupyter_contrib_nbextensions<br>
#  2) pip install jupyter_nbextensions_configurator<br>
#  3) jupyter contrib nbextension install --user<br>
#  4) jupyter nbextensions_configurator enable --user<br>
#
# **``STEP 2:``** ``Open jupyter notebook``
#  - click on nbextensions tab<br>
#  - unckeck disable configuration for nbextensions without explicit compatibility<br>
#  - put a check on Hinterland<br>
#
# **``Step 3:``** ``Open new python file and check autocomplete feature``
#
# [VIDEO SOURCE](https://www.youtube.com/watch?v=DKE8hED0fow)
#
# ![Image_Assignment](https://i.ibb.co/RbmDmD6/E8-EED4-F3-B3-F4-4571-B6-A0-1-B3224-AAB060-4-5005-c.jpg)

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">IMPORTING LIBRARIES NEEDED IN THIS STUDY</p>
#
# <a id="1"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# Once you've installed NumPy and Pandas you can import them as a library. Then read the dataset and assig it as **``"ecom"``**:

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# To unzip the zipped files, first install the two modules for python using, as usual, **``!pip install``** command
#
# patool<br>
# pyunpack

# %% [raw]
# 📝How to Open rar in jupyter ✍
#
# import patoolib
# patoolib.extract_archive("data.7z")
#
#
# The zipped file will be extracted to your local directory where you work even if you don't define "outdir" parameter. And the output will present the following:
#
# patool: Extracting data.7z ...
# patool: running C:\Users\tuseb.000\anaconda3\Library\bin\7z.EXE x -o.\Unpack_7s3qxtnj -- data.7z
# patool: ... data.7z extracted to `data.csv'.
# 'data.csv'
#
# Then you can read your file as usual:
#
# pd.read_csv('data.csv', encoding='unicode_escape')

# %%
# !pip install unrar

# %%
# !pip install patool

# conda install -c conda-forge patool (anaconda prompt)

# %%
# The first method to unzip

import patoolib

patoolib.extract_archive("data.rar")

pd.read_csv('data.csv', encoding='unicode_escape')
# Out:
# patool: Extracting data.rar ...
# patool: running "C:\Program Files\WinRAR\rar.EXE" x -- D:\GITHUB\DS_C12_EU\DATA_ANALYTICS_MODULE\00_Assignments&Projects\data.rar
# patool:     with cwd=.\Unpack_ifi84g7h
# patool: ... data.rar extracted to `data5' (local file exists).
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# !pip install pyunpack

# %%
# The second method to unzip

# from pyunpack import Archive
# import patoolib

# Archive("data.7z").extractall(".")  # "." is current directory

# %%
# !pip install py7zr

# %%
# The third method to unzip

from py7zr import unpack_7zarchive
import shutil

# # You need to run the following code at the first attemp for 7z extension
# shutil.register_unpack_format('7zip', ['.7z'], unpack_7zarchive)

shutil.unpack_archive('data.7z', '.')
pd.read_csv('data.csv', encoding='unicode_escape')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
# The fourth method to unzip, if the extension of file is ".zip"

import zipfile

pd.read_csv('data.zip', encoding='unicode_escape')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df = pd.read_csv('data.csv', encoding='unicode_escape')
ecom = df.copy()
ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ### 🔥 SPECIAL NOTE! 🔥
#
# **If "MemoryError" occurs, take only the first 100 rows or some part of DataFrame**
#
# **[Not reading all rows while importing csv into pandas dataframe](https://stackoverflow.com/questions/33161769/not-reading-all-rows-while-importing-csv-into-pandas-dataframe)**

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 01: Check the Head of the DataFrame</p>
#
# <a id="2"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 5  12/1/2010 8:26       7.65     17850.0  United Kingdom
# 6  12/1/2010 8:26       4.25     17850.0  United Kingdom
# 7  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 8  12/1/2010 8:28       1.85     17850.0  United Kingdom
# 9  12/1/2010 8:34       1.69     13047.0  United Kingdom

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 02: How many rows and columns are there?</p>
#
# <a id="3"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
ecom.shape
# Out:
# (541909, 8)

# %%
rows = len(ecom.axes[0])
cols = len(ecom.axes[1])
  
print("Number of Rows: " + str(rows))
print("Number of Columns: " + str(cols))
# Out:
# Number of Rows: 541909
# Number of Columns: 8

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 03: What is the average of Product sold and the average price of Product per unit?</p>
#
# <a id="4"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom['UnitPrice'].mean()
# Out:
# 4.611113626083471

# %%
ecom['Quantity'].mean()
# Out:
# 9.55224954743324

# %%
np.mean(ecom[['UnitPrice', "Quantity"]])

# ecom[['UnitPrice', "Quantity"]].mean(axis=0)
# Out:
# UnitPrice    4.611114
# Quantity     9.552250
# dtype: float64

# %%
a=ecom["UnitPrice"].mean()
b=ecom["Quantity"].mean()
ser= pd.Series({"UnitPrice":a,"Quantity":b})#böyle de yapılabilir
ser
# Out:
# UnitPrice    4.611114
# Quantity     9.552250
# dtype: float64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 04: What are the highest and lowest purchase prices?</p>
#
# <a id="5"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom['UnitPrice'].max()

# ecom.loc[ecom.UnitPrice.idxmax()]['UnitPrice']
# ecom.UnitPrice.nlargest(1).values[0]
# np.max(ecom.UnitPrice)
# Out:
# 38970.0

# %%
ecom['UnitPrice'].min()

# ecom.loc[ecom.UnitPrice.idxmin()]['UnitPrice']
# ecom.UnitPrice.nsmallest(1).values[0]
# np.min(ecom.UnitPrice)
# Out:
# -11062.06

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 05: List the country names and number of their records belongs to each country</p>
#
# <a id="6"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.Country.value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 06: How many records are there in the United Kingdom?</p>
#
# <a id="7"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom[ecom['Country']=='United Kingdom'].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %%
ecom.groupby("Country").count().loc["United Kingdom"]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 07: Create a column named "Total" which shows the total amount of spend using UnitPrice and Quantity</p>
#
# <a id="8"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom['Total'] = ecom['UnitPrice'] * ecom['Quantity']
ecom['Total']
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34

# %%
# x=ecom.loc[ecom["Country"]=="United Kingdom"]
# x.head()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 08: Show total spending amount according to the Countries and their percentages.</p>
#
# <a id="9"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.groupby('Country')['Total'].sum()
# Out:
# Country
# Australia                137077.270
# Austria                   10154.320
# Bahrain                     548.400
# Belgium                   40910.960
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20086.290
# Cyprus                    12946.290
# Czech Republic              707.720
# Denmark                   18768.140
# EIRE                     263276.820
# European Community         1291.750
# Finland                   22326.740
# France                   197403.900
# Germany                  221698.210
# Greece                     4710.520
# Hong Kong                 10117.040
# Iceland                    4310.000
# Israel                     7907.820
# Italy                     16890.510
# Japan                     35340.620
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2505.470
# Netherlands              284661.540
# Norway                    35163.460
# Poland                     7213.140
# Portugal                  29367.020
# RSA                        1002.310
# Saudi Arabia                131.170
# Singapore                  9120.390
# Spain                     54774.580
# Sweden                    36595.910
# Switzerland               56385.350
# USA                        1730.920
# United Arab Emirates       1902.280
# United Kingdom          8187806.364
# Unspecified                4749.790
# Name: Total, dtype: float64

# %%
total_purchase = ecom['Total'].sum()
total_purchase_by_country = ecom.groupby('Country')['Total'].sum()
perc_by_country = (total_purchase_by_country / total_purchase) * 100
perc_by_country.sort_values(ascending=False)

# (ecom.groupby("Country")["Total"].apply(lambda x: x.sum())/ecom.groupby("Country")["Total"].apply(lambda x: x.sum()).sum()*100).sort_values(ascending=False)

# A=ecom.groupby('Country')['Total'].sum()/ecom.Total.sum() *100
# A.sort_values(ascending=False)
# Out:
# Country
# United Kingdom          83.996903
# Netherlands              2.920280
# EIRE                     2.700899
# Germany                  2.274353
# France                   2.025123
# Australia                1.406246
# Switzerland              0.578445
# Spain                    0.561920
# Belgium                  0.419697
# Sweden                   0.375429
# Japan                    0.362552
# Norway                   0.360734
# Portugal                 0.301270
# Finland                  0.229045
# Channel Islands          0.206061
# Denmark                  0.192538
# Italy                    0.173276
# Cyprus                   0.132813
# Austria                  0.104171
# Hong Kong                0.103788
# Singapore                0.093564
# Israel                   0.081125
# Poland                   0.073998
# Unspecified              0.048727
# Greece                   0.048324
# Iceland                  0.044215
# Canada                   0.037613
# Malta                    0.025703
# United Arab Emirates     0.019515
# USA                      0.017757
# Lebanon                  0.017377
# Lithuania                0.017040
# European Community       0.013252
# Brazil                   0.011732
# RSA                      0.010282
# Czech Republic           0.007260
# Bahrain                  0.005626
# Saudi Arabia             0.001346
# Name: Total, dtype: float64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 09: Which Country spend least?</p>
#
# <a id="10"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.groupby('Country')['Total'].sum().sort_values(ascending=True)[:1]
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %%
pd.DataFrame(ecom.groupby('Country')['Total'].sum().sort_values(ascending=True)).reset_index().iloc[0]
# Out:
# Country    Saudi Arabia
# Total            131.17
# Name: 0, dtype: object

# %%
ecom.groupby('Country')['Total'].sum().nsmallest(1)
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %%
ecom.groupby("Country")["Total"].sum().sort_values().head(1)
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %%
ecom.groupby("Country")["Total"].sum().sort_values()[:1]

# %%
ecom.groupby(["Country"])["Total"].sum()[
    ecom.groupby("Country")["Total"].sum() == 
    ecom.groupby(["Country"])[["Total"]].sum().min()[0]
]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 10: Calculate the average of spending according to country with apply function and create a new feature named "Average_Spend"</p>
#
# <a id="11"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.groupby('Country')['Total'].apply(np.mean)

# ecom.groupby("Country")["Total"].apply(lambda x: x.mean())
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %%
ecom["Average_Spend"] = ecom.groupby('Country')['Total'].transform("mean")
ecom.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total  Average_Spend
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30      16.525065
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34      16.525065
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00      16.525065

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 11: Calculate average, min, max of spending according to country with agg() function and create new features named "Max_Spend" and "Min_Spend"</p>
#
# <a id="12"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.groupby('Country')['Total'].agg({'min', 'mean', 'max'})

# ecom.groupby("Country")["Total"].agg([min,np.mean,max])
# Out:
#                             min        mean        max
# Country
# Australia               -425.00  108.877895    1718.40
# Austria                  -21.25   25.322494     360.00
# Bahrain                 -205.74   28.863158     205.74
# Belgium                  -19.95   19.773301     165.00
# Brazil                    15.00   35.737500     175.20
# Canada                     2.50   24.280662     550.94
# Channel Islands         -293.00   26.499063     408.00
# Cyprus                  -320.69   20.813971     320.69
# Czech Republic           -35.76   23.590667      70.80
# Denmark                  -59.80   48.247147     428.40
# EIRE                   -1917.00   32.122599    2365.20
# European Community        -8.50   21.176230      60.00
# Finland                  -80.00   32.124806     551.20
# France                 -8322.12   23.069288    4161.06
# Germany                 -599.50   23.348943     876.00
# Greece                   -50.00   32.263836     175.20
# Hong Kong              -2653.95   35.128611    2653.95
# Iceland                    5.04   23.681319     249.60
# Israel                  -136.00   26.625657     350.40
# Italy                    -89.55   21.034259     300.00
# Japan                  -1591.20   98.716816    3794.40
# Lebanon                   10.20   37.641778     153.00
# Lithuania                 13.20   47.458857     122.40
# Malta                   -130.00   19.728110     455.00
# Netherlands             -266.40  120.059696    4992.00
# Norway                  -376.50   32.378877     700.00
# Poland                   -39.80   21.152903     120.00
# Portugal               -1241.98   19.333127    1241.98
# RSA                        0.00   17.281207      38.25
# Saudi Arabia             -14.75   13.117000      19.80
# Singapore              -3949.32   39.827031    3949.32
# Spain                  -1715.85   21.624390    1350.00
# Sweden                 -1188.00   79.211926    1188.00
# Switzerland             -179.00   28.164510     360.00
# USA                      -74.88    5.948179      81.36
# United Arab Emirates       3.48   27.974706     153.00
# United Kingdom       -168469.60   16.525065  168469.60
# Unspecified                0.19   10.649753      69.36

# %%
ecom["Max_Spend"] = ecom.groupby('Country')['Total'].transform("max")
ecom["Min_Spend"] = ecom.groupby('Country')['Total'].transform("min")

# ecom["Max_Spend"] = ecom.groupby("Country")["Total"].transform(lambda x: x.max())
# ecom["Min_Spend"] = ecom.groupby("Country")["Total"].transform(lambda x: x.min())

# ecom['Max_Spend']=ecom.groupby("Country")["Total"].transform(np.max)
# ecom["Min_Spend"]=ecom.groupby("Country")["Total"].transform(min)

ecom
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# ...                 ...        ...         ...             ...    ...
# 541904  12/9/2011 12:50       0.85     12680.0          France  10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France  12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France  16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France  14.85
#
#         Average_Spend  Max_Spend  Min_Spend
# 0           16.525065  168469.60 -168469.60
# 1           16.525065  168469.60 -168469.60
# 2           16.525065  168469.60 -168469.60
# 3           16.525065  168469.60 -168469.60
# 4           16.525065  168469.60 -168469.60
# ...               ...        ...        ...
# 541904      23.069288    4161.06   -8322.12
# 541905      23.069288    4161.06   -8322.12
# 541906      23.069288    4161.06   -8322.12
# 541907      23.069288    4161.06   -8322.12
# 541908      23.069288    4161.06   -8322.12
#
# [541909 rows x 12 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 12: What is the max Total spending in whole dataset and show all records of that spending?</p>
#
# <a id="13"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom[ecom.Total == ecom.Total.max()]

# ecom.iloc[[ecom.Total.idxmax()]]
# ecom.loc[ecom.Total.idxmax()].to_frame().T
# ecom.sort_values(by = "Total", ascending = False).head(1)
# ecom.loc[[ecom.Total.argmax()]]
# ecom.[ecom["Total"] == ecom[["Max_Spend"]].max()[0]]
# ecom.loc[[ecom.Total.idxmax()]]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total  \
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6
#
#         Average_Spend  Max_Spend  Min_Spend
# 540421      16.525065   168469.6  -168469.6

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 13: How many people who live in Spain spend more than average Total?</p>
#
# <a id="14"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom[(ecom.Total > ecom.Total.mean()) & (ecom.Country == 'Spain')].count()

#cond1=ecom[ecom["Total"] >ecom["Total"].mean()][ecom["Country"] == 'Spain'].count()
# cond2=ecom.loc[ecom["Total"] >ecom["Total"].mean()][ecom["Country"] == 'Spain'].count()
# print(cond1,'\n')
# print(cond2)

# ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())].count()
# Out:
# InvoiceNo        728
# StockCode        728
# Description      728
# Quantity         728
# InvoiceDate      728
# UnitPrice        728
# CustomerID       728
# Country          728
# Total            728
# Average_Spend    728
# Max_Spend        728
# Min_Spend        728
# dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 14: Convert datatype of "InvoiceDate" to datetime and assign it to new column named "InvoiceDate2"</p>
#
# <a id="15"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom['InvoiceDate'].dtype
# Out:
# dtype('O')

# %%
ecom['InvoiceDate2'] = pd.to_datetime(ecom.InvoiceDate)
# ecom['InvoiceDate2'] = ecom['InvoiceDate'].astype('datetime64[ns]')
# df["InvoiceDate2"] = df["InvoiceDate"].astype("datetime64")
ecom['InvoiceDate2']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   InvoiceNo      541909 non-null  object
#  1   StockCode      541909 non-null  object
#  2   Description    540455 non-null  object
#  3   Quantity       541909 non-null  int64
#  4   InvoiceDate    541909 non-null  object
#  5   UnitPrice      541909 non-null  float64
#  6   CustomerID     406829 non-null  float64
#  7   Country        541909 non-null  object
#  8   Total          541909 non-null  float64
#  9   Average_Spend  541909 non-null  float64
#  10  Max_Spend      541909 non-null  float64
#  11  Min_Spend      541909 non-null  float64
#  12  InvoiceDate2   541909 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(6), int64(1), object(5)
# memory usage: 53.7+ MB

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 15: Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named **``date``**</p>
#
# <a id="16"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.InvoiceDate2
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate2, Length: 541909, dtype: datetime64[ns]

# %%
ecom['date'] = ecom.InvoiceDate2.dt.date

# ecom["date"] = pd.to_datetime(ecom['InvoiceDate2']).dt.strftime('%Y-%m-%d')

# pd.to_datetime(ecom["InvoiceDate"]).dt.normalize()

# pd.to_datetime(ecom['InvoiceDate2'],format='%Y-%m-%d').dt.to_period('D')

# ecom["date"] = ecom.InvoiceDate2.astype(str).transform(lambda x: x[:10])

# ecom["date"] =  pd.to_datetime(ecom["InvoiceDate2"], format="%y/%m/%d")

# %%
ecom['date']
# Out:
# 0         2010-12-01
# 1         2010-12-01
# 2         2010-12-01
# 3         2010-12-01
# 4         2010-12-01
#              ...
# 541904    2011-12-09
# 541905    2011-12-09
# 541906    2011-12-09
# 541907    2011-12-09
# 541908    2011-12-09
# Name: date, Length: 541909, dtype: object

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  15.30
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom  22.00
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom  20.34
#
#    Average_Spend  Max_Spend  Min_Spend        InvoiceDate2        date
# 0      16.525065   168469.6  -168469.6 2010-12-01 08:26:00  2010-12-01
# 1      16.525065   168469.6  -168469.6 2010-12-01 08:26:00  2010-12-01
# 2      16.525065   168469.6  -168469.6 2010-12-01 08:26:00  2010-12-01
# 3      16.525065   168469.6  -168469.6 2010-12-01 08:26:00  2010-12-01
# 4      16.525065   168469.6  -168469.6 2010-12-01 08:26:00  2010-12-01

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 16: Drop "InvoiceDate2" and "InvoiceDate" columns permanently</p>
#
# <a id="17"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.drop(['InvoiceDate2', 'InvoiceDate'], axis=1, inplace=True)
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  Total  Average_Spend  Max_Spend  \
# 0       2.55     17850.0  United Kingdom  15.30      16.525065   168469.6
# 1       3.39     17850.0  United Kingdom  20.34      16.525065   168469.6
# 2       2.75     17850.0  United Kingdom  22.00      16.525065   168469.6
# 3       3.39     17850.0  United Kingdom  20.34      16.525065   168469.6
# 4       3.39     17850.0  United Kingdom  20.34      16.525065   168469.6
#
#    Min_Spend        date
# 0  -168469.6  2010-12-01
# 1  -168469.6  2010-12-01
# 2  -168469.6  2010-12-01
# 3  -168469.6  2010-12-01
# 4  -168469.6  2010-12-01

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 17: Remove A, B, G and E characters at the first 5 rows of "StockCode" in ecom dataframe with a string method</p>
#
# <a id="18"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.StockCode[:5]
# Out:
# 0    85123A
# 1     71053
# 2    84406B
# 3    84029G
# 4    84029E
# Name: StockCode, dtype: object

# %%
ecom.StockCode[:5].str.replace('A', '').str.replace('B', '').str.replace('G', '').str.replace('E', '')

# ecom["StockCode"].apply(lambda x: x.replace(x[-1], "") if x.isdigit() == False else x).head()

# ecom.loc[:4,"StockCode"].replace(["A$","B$","G$","E$"],"",regex=True)

# ecom['StockCode'].str.replace("[A,B,G,E]","").head()

# ecom['StockCode'][:5].map(lambda x: x.rstrip('ABGE'))

# ecom.iloc[0:5]["StockCode"].str.replace("A|B|G|E", "", regex=True)

# #ecom["StockCode"].iloc[:5].str.replace(pat=r"([A-Z]+)", repl="",regex=True)

# ecom["StockCode"].head().str.replace("[ABGE]", "")

# ecom.iloc[:5,1].replace(r'\D', r'', regex=True)

# ecom.iloc[:5].loc[ecom.StockCode.str.contains("A|B|G|E|71053", case=False)].StockCode.str.replace("A|B|G|E","",regex = True)

# ecom.StockCode.head().replace({'A':'','B':'','G':'','E':''}, regex = True)

# ecom.iloc[:5]["StockCode"].map(lambda x : x[:-1] if x[-1].isalpha() else x)
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
def function(x):
    result = ""
    for i in x:
        if i.isdigit():
            result += i
    return result

ecom.iloc[0:5,1].apply(function)
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
for i in "ABGE":
    ecom.loc[:5,"StockCode"] = ecom.loc[:5,"StockCode"].head(5).str.removesuffix((i))
    
ecom["StockCode"].head(5)
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
ecom.StockCode[:5]
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %%
ecom.StockCode.str.extract("(\d+)")
# Out:
#             0
# 0       85123
# 1       71053
# 2       84406
# 3       84029
# 4       84029
# ...       ...
# 541904  22613
# 541905  22899
# 541906  23254
# 541907  23255
# 541908  22138
#
# [541909 rows x 1 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 18: Take only "Total" and "date" columns with loc and craete a new df named "ecom2"</p>
#
# <a id="19"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom2 = ecom.loc[:, 'Total':'date']

# ecom.iloc[:,7:]

ecom2
# Out:
#         Total  Average_Spend  Max_Spend  Min_Spend        date
# 0       15.30      16.525065  168469.60 -168469.60  2010-12-01
# 1       20.34      16.525065  168469.60 -168469.60  2010-12-01
# 2       22.00      16.525065  168469.60 -168469.60  2010-12-01
# 3       20.34      16.525065  168469.60 -168469.60  2010-12-01
# 4       20.34      16.525065  168469.60 -168469.60  2010-12-01
# ...       ...            ...        ...        ...         ...
# 541904  10.20      23.069288    4161.06   -8322.12  2011-12-09
# 541905  12.60      23.069288    4161.06   -8322.12  2011-12-09
# 541906  16.60      23.069288    4161.06   -8322.12  2011-12-09
# 541907  16.60      23.069288    4161.06   -8322.12  2011-12-09
# 541908  14.85      23.069288    4161.06   -8322.12  2011-12-09
#
# [541909 rows x 5 columns]

# %%
ecom2 = ecom.loc[:, ['Total', 'date']]
ecom2

# ecom2 = ecom[['Total', 'date']].copy()
# ecom2
# Out:
#         Total        date
# 0       15.30  2010-12-01
# 1       20.34  2010-12-01
# 2       22.00  2010-12-01
# 3       20.34  2010-12-01
# 4       20.34  2010-12-01
# ...       ...         ...
# 541904  10.20  2011-12-09
# 541905  12.60  2011-12-09
# 541906  16.60  2011-12-09
# 541907  16.60  2011-12-09
# 541908  14.85  2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 19: Take only "InvoiceNo" "CustomerID" and "Total" columns with iloc and craete a new df named **``ecom3``**</p>
#
# <a id="20"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365     85123  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365     84406      CREAM CUPID HEARTS COAT HANGER         8
#
#    UnitPrice  CustomerID         Country  Total  Average_Spend  Max_Spend  \
# 0       2.55     17850.0  United Kingdom  15.30      16.525065   168469.6
# 1       3.39     17850.0  United Kingdom  20.34      16.525065   168469.6
# 2       2.75     17850.0  United Kingdom  22.00      16.525065   168469.6
#
#    Min_Spend        date
# 0  -168469.6  2010-12-01
# 1  -168469.6  2010-12-01
# 2  -168469.6  2010-12-01

# %%
ecom3 = ecom.iloc[:, [0, 5, 7]]
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 20: Combine "ecom2" and "ecom3" with concat() method</p>
#
# <a id="21"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom_concat = pd.concat([ecom2, ecom3], axis=1)
ecom_concat
# Out:
#         Total        date InvoiceNo  CustomerID  Total
# 0       15.30  2010-12-01    536365     17850.0  15.30
# 1       20.34  2010-12-01    536365     17850.0  20.34
# 2       22.00  2010-12-01    536365     17850.0  22.00
# 3       20.34  2010-12-01    536365     17850.0  20.34
# 4       20.34  2010-12-01    536365     17850.0  20.34
# ...       ...         ...       ...         ...    ...
# 541904  10.20  2011-12-09    581587     12680.0  10.20
# 541905  12.60  2011-12-09    581587     12680.0  12.60
# 541906  16.60  2011-12-09    581587     12680.0  16.60
# 541907  16.60  2011-12-09    581587     12680.0  16.60
# 541908  14.85  2011-12-09    581587     12680.0  14.85
#
# [541909 rows x 5 columns]

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 21: Combine the common (intersected) values of "ecom2" and "ecom3" with merge() method</p>
#
# <a id="22"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **If "MemoryError" occurs, take only the first 100 rows from both DFs**

# %%
ecom2.head(3)
# Out:
#    Total        date
# 0  15.30  2010-12-01
# 1  20.34  2010-12-01
# 2  22.00  2010-12-01

# %%
ecom3.head(3)
# Out:
#   InvoiceNo  CustomerID  Total
# 0    536365     17850.0  15.30
# 1    536365     17850.0  20.34
# 2    536365     17850.0  22.00

# %%
merged_ecom = pd.merge(ecom2[:100], ecom3[:100], how='inner', on='Total')
merged_ecom
# Out:
#      Total        date InvoiceNo  CustomerID
# 0     15.3  2010-12-01    536365     17850.0
# 1     15.3  2010-12-01    536373     17850.0
# 2     15.3  2010-12-01    536373     17850.0
# 3     15.3  2010-12-01    536375     17850.0
# 4     15.3  2010-12-01    536375     17850.0
# ..     ...         ...       ...         ...
# 395   13.2  2010-12-01    536378     14688.0
# 396   13.2  2010-12-01    536378     14688.0
# 397   13.2  2010-12-01    536378     14688.0
# 398   13.2  2010-12-01    536378     14688.0
# 399   13.2  2010-12-01    536378     14688.0
#
# [400 rows x 4 columns]

# %%
# merged_ecom.duplicated().sum()

# %%
# ecom2 = ecom2.drop_duplicates()

# %%
# ecom3 = ecom3.drop_duplicates()

# %%
# merged_ecom = pd.merge(ecom2[:100], ecom3[:100], how='inner', on='Total')
# merged_ecom

# %%
ecom2.drop("Total", axis=1, inplace=True)
mrg_ecom2 = pd.merge(left=ecom2[:100], right=ecom3[:100], how="inner", left_index=True, right_index=True)
mrg_ecom2
# Out:
#           date InvoiceNo  CustomerID  Total
# 0   2010-12-01    536365     17850.0  15.30
# 1   2010-12-01    536365     17850.0  20.34
# 2   2010-12-01    536365     17850.0  22.00
# 3   2010-12-01    536365     17850.0  20.34
# 4   2010-12-01    536365     17850.0  20.34
# ..         ...       ...         ...    ...
# 95  2010-12-01    536378     14688.0  15.30
# 96  2010-12-01    536378     14688.0  50.40
# 97  2010-12-01    536378     14688.0  13.20
# 98  2010-12-01    536378     14688.0  13.20
# 99  2010-12-01    536378     14688.0  13.20
#
# [100 rows x 4 columns]

# %%
ecom2
# Out:
#               date
# 0       2010-12-01
# 1       2010-12-01
# 2       2010-12-01
# 3       2010-12-01
# 4       2010-12-01
# ...            ...
# 541904  2011-12-09
# 541905  2011-12-09
# 541906  2011-12-09
# 541907  2011-12-09
# 541908  2011-12-09
#
# [541909 rows x 1 columns]

# %%
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %%
# ecom2["index_no"] = ecom2.index
# ecom32["index_no"] = ecom32.index

# ecom2 = ecom2.iloc[:100]
# ecom32 = ecom32.iloc[:100]

# mrg_df = pd.merge(left = ecom2, right = ecom32, how = "inner")
# mrg_df.drop("index_no", axis = 1, inplace= True)
# mrg_df

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Task 22: Combine "ecom2" and "ecom3" with join() method</p>
#
# <a id="23"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>

# %%
ecom2.join(ecom3, how='inner', lsuffix='_left', rsuffix='_right')
# Out:
#               date InvoiceNo  CustomerID  Total
# 0       2010-12-01    536365     17850.0  15.30
# 1       2010-12-01    536365     17850.0  20.34
# 2       2010-12-01    536365     17850.0  22.00
# 3       2010-12-01    536365     17850.0  20.34
# 4       2010-12-01    536365     17850.0  20.34
# ...            ...       ...         ...    ...
# 541904  2011-12-09    581587     12680.0  10.20
# 541905  2011-12-09    581587     12680.0  12.60
# 541906  2011-12-09    581587     12680.0  16.60
# 541907  2011-12-09    581587     12680.0  16.60
# 541908  2011-12-09    581587     12680.0  14.85
#
# [541909 rows x 4 columns]

# %%
ecom.groupby("Country")["Total"].sum().sort_values(ascending = False) / ecom["Total"].sum() * 100
# Out:
# Country
# United Kingdom          83.996903
# Netherlands              2.920280
# EIRE                     2.700899
# Germany                  2.274353
# France                   2.025123
# Australia                1.406246
# Switzerland              0.578445
# Spain                    0.561920
# Belgium                  0.419697
# Sweden                   0.375429
# Japan                    0.362552
# Norway                   0.360734
# Portugal                 0.301270
# Finland                  0.229045
# Channel Islands          0.206061
# Denmark                  0.192538
# Italy                    0.173276
# Cyprus                   0.132813
# Austria                  0.104171
# Hong Kong                0.103788
# Singapore                0.093564
# Israel                   0.081125
# Poland                   0.073998
# Unspecified              0.048727
# Greece                   0.048324
# Iceland                  0.044215
# Canada                   0.037613
# Malta                    0.025703
# United Arab Emirates     0.019515
# USA                      0.017757
# Lebanon                  0.017377
# Lithuania                0.017040
# European Community       0.013252
# Brazil                   0.011732
# RSA                      0.010282
# Czech Republic           0.007260
# Bahrain                  0.005626
# Saudi Arabia             0.001346
# Name: Total, dtype: float64

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">THE END OF THE ASSIGNMENT 02</p>
#
# # Now. it's time to relax!
#
# ![Image_Assignment](https://i.ibb.co/jZD3Mqb/relaxing.jpg)
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
#
# <a id="24"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
# ___

# %%
ecom.loc[ecom["Country"] == "United Kingdom"].count()
# Out:
# InvoiceNo        495478
# StockCode        495477
# Description      494024
# Quantity         495478
# UnitPrice        495478
# CustomerID       361878
# Country          495478
# Total            495478
# Average_Spend    495478
# Max_Spend        495478
# Min_Spend        495478
# date             495478
# dtype: int64
